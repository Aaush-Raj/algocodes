# %%
input_data = {'csrfmiddlewaretoken': ['kZ3gXcfFmP8UVb6oEc1UNTqZ4FytjoG6NHMswCePImg8q8bM7zqAQYBz307cZgSH'],
              'legcount': ['0'],
              'algoname': ['TESTALGO2'],
              'instrument': ['Banknifty'],
              'segment': ['Options'],
              'options': ['PE'],
              'transcation_type': ['Buy'], 
              'strike': ['ATM'],
              'quantity': ['25'],
              'target': ['50'], 
              'stoploss': ['50'],
              'startTime': ['09:30'],
              'endTime': ['15:10'], 
              'move_sl_to_cost': ['move_sl_to_cost'],
              'square_off': ['square_off']}

input_data = {'csrfmiddlewaretoken': ['lxaY0uksyUhQVyF3w2GGQbijEo1K70QVOfTazUjCUrp4qvKrZp5mTgtTDJAtNS2w'], 
           'legcount': ['2'],
           'algoname': ['TEST@Aaush'],
           'instrument': ['Nifty', 'Nifty'],
           'segment': ['Options', 'Options'],
           'options': ['PE', 'CE'],
           'transcation_type': ['Buy', 'Sell'],
           'strike': ['ATM', 'ATM'],
           'lots': ['5', '9'],
           'target': ['100', '100'],
           'stoploss': ['50', '25'], 
           
           'startTime': ['09:15'],
           'endTime': ['15:15'],
           'move_sl_to_cost': ['move_sl_to_cost'],
           'square_off': ['square_off']}

# print(input_data)

# %%
statergy_920 = {"legcount": '2',
           "algoname": 'BNF920',
           "instrument": ['Nifty', 'Nifty'],
           "segment": ['Options', 'Options'],
           "options": ['PE', 'CE'],
           "transcation_type": ['Buy', 'Sell'],
           "strike": ['ATM', 'ATM'],
           "lots": ['5', '9'],
           "target": ['100', '100'],
           "stoploss": ['50', '25'], 
           "startTime": ['9','15'],
           "endTime": ['15','10'],
           "move_sl_to_cost": None,
           "square_off": None}



{
  "legcount": "2",
   "algoname": "BNF920",
   "instrument": ["Nifty", "Nifty"],
   "segment": ["Options", "Options"],
   "options": ["PE", "CE"],
   "transcation_type": ["Buy", "Sell"],
   "strike": ["ATM", "ATM"],
   "lots": ["5", "9"],
   "target": ["100", "100"],
   "stoploss": ["50", "25"], 
   "startTime": ["9","15"],
   "endTime": ["15","10"],
   "move_sl_to_cost": None,
   "square_off": None
}

# %%
def main(algoname=None,instrument=None,segment='Options',options=None,transcation_type):
    print(algoname)
    if algoname ==None:
        print("GO AWAY")
    
main()

# %%
from _thread import start_new_thread
from time import sleep

import pymongo
from pymongo import MongoClient
import ssl
from pya3 import *

def scheduled_task():
    client = pymongo.MongoClient("mongodb+srv://aaush:AaushMongoTestAccount@gopassive.niccs6s.mongodb.net/?retryWrites=true&w=majority",ssl_cert_reqs=ssl.CERT_NONE)
    db = client['AlgoTrade']
    scheduler_col =db['scheduled_data']
    algo_data_col =db['test_statergies']
    all_scheduled_data = list(scheduler_col.find({}))
    
    
    for scheduled_data in all_scheduled_data:
        username = scheduled_data['username']
        api_key = scheduled_data['api_key']
        scheduled_algo = scheduled_data['scheduled_algo']
        status = scheduled_data['status']
        algo_data = algo_data_col.find_one({'_id':scheduled_algo })
        
        start_new_thread(main,(username,api_key,algo_data))
        print("STARTED THE ALGO FOR",username,"ALGO->"+scheduled_algo)
        
scheduled_task()
# Out:
# STARTED THE ALGO FOR 285915 ALGO->BNF930
# STARTED THE ALGO FOR 285915 ALGO->NF920
# Exception ignored in thread started by: <function main at 0x000002A13BFA9D30>
# Traceback (most recent call last):
#   File "<ipython-input-45-43dcc7fb02cc>", line 11, in main
# TypeError: 'NoneType' object is not subscriptable
# Exception ignored in thread started by: <function main at 0x000002A13BFA9D30>
# Traceback (most recent call last):
#   File "<ipython-input-45-43dcc7fb02cc>", line 31, in main
# NameError: name 'algoname' is not defined
# ALGONAME NF920

# %%
order_id_list = []
order_list = []
sl_order_list = []
def main(username,api_key,input_data):
    global alice
    
    alice = Aliceblue(user_id=username,api_key=api_key)
    alice.get_session_id()
    
    
    algoName = input_data['algoname']
    instrument = input_data['instrument']
    segment = input_data['segment']
    options = input_data['options']
    transcation_type = input_data['transcation_type']
    strike = input_data['strike']
    lots = input_data['lots']
    target = input_data['target']
    stoploss = input_data['stoploss']
#     is_ce= input_data['is_ce']
    
    #below are singular list data
    startTime = input_data['startTime']
    endTime = input_data['endTime']
    move_sl_to_cost = input_data['move_sl_to_cost']
    square_off = input_data['square_off']
    print("ALGONAME "+algoName)
    
#     while datetime.datetime.now().time() < datetime.time(startTime[0],startTime[1])
    for i in range(len(instrument)):
        print(algoname)
        start_new_thread(place_orders,(transcation_type[i],instrument[i].upper(),lots[i],options[i],strike[i],stoploss[i],target[i]))
        print(transcation_type[i],instrument[i].upper(),lots[i],options[i],strike[i],stoploss[i],target[i])
        
    
    
def place_orders(transaction_type,inst,lots,option,strike,stoploss,target):
    
    if strike == 'ATM':
        info = alice.get_instrument_by_token('INDICES', 26000)
    
    exp = '2023-1-12' 
    
    print(option)
    
    if option == 'CE':
        is_ce = True
    else:
        is_ce = False
        
    print(is_ce)
    
    if inst.upper() =='NIFTY':
        qty = 50*int(lots)
        print(alice.get_scrip_info(alice.get_instrument_by_token('INDICES', 26000)))
        strike = int(round(float(alice.get_scrip_info(alice.get_instrument_by_token('INDICES', 26000))['LTP'])/50)*50)
        print(strike)

    else:
        qty = 25*int(lots)
        strike = int(round(float(alice.get_scrip_info(alice.get_instrument_by_token('INDICES', 26009))['LTP'])/100)*100)

    
    if transaction_type == 'BUY':
        ttype = TransactionType.Buy
        sl_ttype = TransactionType.Sell
    else:
        ttype = TransactionType.Sell
        sl_ttype = TransactionType.Buy
        

    instrument =alice.get_instrument_for_fno(exch = 'NFO',symbol=inst,expiry_date=exp,is_fut=False,strike=strike,is_CE=is_ce)
    print("INSTRUMENT-->",instrument)
    order = alice.place_order(transaction_type = ttype,
                     instrument = instrument,
                     quantity = qty,
                     order_type = OrderType.Market,
                     product_type = ProductType.Intraday,
                     price = 0.0,
                     trigger_price = None,
                     stop_loss = None,
                     square_off = None,
                     trailing_sl = None,
                     is_amo = False)
    print(order)
#     sleep(1)
    oid = order['NOrdNo']
    order_id_list.append(oid)
    avg_p = int(get_avg_prc(oid))
    print(avg_p)
    print(stoploss,"Points on Avg_prc Was given as stoploss")
    print(target,"Points on Avg_prc Was given as Target")
    
    
#     sl_price = 0.5* (float(avg_p - stoploss)/0.5)
    if transaction_type == 'BUY':
        sl_price =float(avg_p - int(stoploss))
        tgt_price = float(avg_p + int(target))
    else:
        sl_price =float(avg_p + int(stoploss))
        tgt_price = float(avg_p - int(target))
        
    print(sl_price,tgt_price)
        
    
    sl_order = alice.place_order(
        transaction_type=sl_ttype,
        instrument=instrument,
        quantity=qty,
        order_type=OrderType.StopLossLimit,
        product_type=ProductType.Intraday,
        price=sl_price,
        trigger_price=(sl_price+1),
        stop_loss=None,
        square_off=None,
        trailing_sl=None,
        is_amo=False)
#     sleep(1)
    sl_oid = sl_order['NOrdNo']
    
    order_list.append(oid)
    sl_order_list.append(sl_oid)
    order_dict[sl_oid] = oid
    
    
    target_order = alice.place_order(transaction_type=ttype,
                                     instrument=instrument,
                                     quantity=qty,
                                     order_type=OrderType.Limit,
                                     product_type=ProductType.Intraday,
                                     price=tgt_price,
                                     trigger_price=None,
                                     stop_loss=None,
                                     square_off=None,
                                     trailing_sl=None,
                                     is_amo=False)


    
    
    
    
    
def place_sl_orders():
#     get_avg_prc(oid)
    pass
def get_avg_prc(oid):
    order_details = alice.get_order_history(oid)
    avg_price = order_details['Avgprc']
    return avg_price

def get_ord_status(oid):
    order_details = alice.get_order_history(oid)
    ord_status = order_details['Status']
    return ord_status

# main(input_data)

# %%
from pya3 import *

username= "285915"
api_key = "eUmxHh0mSZujQ4xGn2Bi5BOgDtVoalyG4ssEzPmFeJy0d0ocPtRhCYC3xZyRZ4S2DPfUq4DsHQxcLqPjnG0CNht5Y1Y5e8XrP8zB97G4ocBf7hljkKKNfsmHyWu2BFb9"
                  
alice = Aliceblue(user_id=username,api_key=api_key)
print(alice.get_session_id())
# alice.get_contract_master("MCX")
# alice.get_contract_master("NFO")
# alice.get_contract_master("NSE")
# alice.get_contract_master("BSE")
# alice.get_contract_master("CDS")
# alice.get_contract_master("BFO")
# alice.get_contract_master("INDICES")
inst = "NIFTY"
exp = '2023-01-12' 
is_ce = True
strike = 17900
instrument =alice.get_instrument_for_fno(exch ="NFO",symbol="NIFTY",expiry_date="2023-01-12",is_fut=False,strike=17900,is_CE=True)
print(instrument)


def order_status(number):
    order_status= None
    for i in range(3):
        print("Trying to get order status")
        try:
            print("try",i)
            order_details = alice.get_order_history(str(number))
            order_status = order_details['Status']
            return order_status
        except Exception as e:
            print({e})
            sleep(25)
            pass
        
print(order_status(230110000252065))
# order = alice.place_order(transaction_type = TransactionType.Sell,
#                      instrument = instrument,
#                      quantity = 50,
#                      order_type = OrderType.Market,
#                      product_type = ProductType.Intraday,
#                      price = 0.0,
#                      trigger_price = None,
#                      stop_loss = None,
#                      square_off = None,
#                      trailing_sl = None,
#                      is_amo = False)

# print(order)
# print(order_status(order['NordNo']))
# Out:
# {'stat': 'Ok', 'sessionID': ''}
# Instrument(exchange='NFO', token=49701, symbol='NIFTY', name='NIFTY2311217900CE', expiry='2023-01-12', lot_size=50)
# Trying to get order status
# try 0
# rejected

# %%
#I have to make a fnc which will take data from the scheduled table ,
# In scheduled table there will be the name and details of client and its to be running statergy

# Step 1-  TO save the scheduled data ,

# %%
# TOTAL TABLES-->
# 1. client data table - This table will consist of all clients and ther broker's data
# 2. statergy table - this will have details of Algos which will be identified by names
# 3. scheduler table - this will have all details of scheduled and algo's to the clients

# %%
scheduled_data = {"client_id":"TESTUSER_01",
                  "username":"285915",
                  "api_key":"eUmxHh0mSZujQ4xGn2Bi5BOgDtVoalyG4ssEzPmFeJy0d0ocPtRhCYC3xZyRZ4S2DPfUq4DsHQxcLqPjnG0CNht5Y1Y5e8XrP8zB97G4ocBf7hljkKKNfsmHyWu2BFb9",
                  "scheduled_algo":"BNF930",
                  "status":"ACTIVE",
                 }

# %%
# getting algo data from it's DB

import pymongo
from pymongo import MongoClient
import ssl

client = pymongo.MongoClient("mongodb+srv://aaush:AaushMongoTestAccount@gopassive.niccs6s.mongodb.net/?retryWrites=true&w=majority",ssl_cert_reqs=ssl.CERT_NONE)

# %%
data = {"_id": "NF920",
  "legcount": 2,
   "algoname": "NF920",
   "instrument": ["Nifty", "Nifty"],
   "segment": ["Options", "Options"],
   "options": ["PE", "CE"],
   "transcation_type": ["Sell", "Sell"],
   "strike": ["ATM", "ATM"],
   "lots": ["5", "5"],
   "target": ["100", "100"],
   "stoploss": ["50", "25"], 
   "startTime": ["9","15"],
   "endTime": ["15","10"],
   "move_sl_to_cost": None,
   "square_off": None
}

{'csrfmiddlewaretoken': ['EB2oocencc0KRPRJSYrSFxidHQDb5K6RMBpTP7YxeiJBKt30adPkD0A0Vft4iotB'], 'legcount': ['2'], 'algoname': ['TEST'], 'instrument': ['Nifty', 'Nifty'], 'segment': ['Options', 'Options'], 'options': ['PE', 'PE'], 'transcation_type': ['Buy', 'Buy'], 'strike': ['ATM', 'ATM'], 'quantity': ['25', '10'], 'target': ['300', '100'], 'stoploss': ['100', '50'], 'startTime': ['20:26'], 'endTime': ['21:26'], 'move_sl_to_cost': ['move_sl_to_cost'], 'square_off': ['square_off']}
# print(client)
db = client['AlgoTrade']
# test_col =db['test_statergies']
test_col =db['scheduled_data']

# test_col.insert_one(data)
all_data = list(test_col.find({}))
# print(list(all_data))
for a in all_data:
    print(a)
    username = a['username']
    api_key = a['api_key']
    scheduled_algo = a['scheduled_algo']
    status = a['status']
    algo_data = 
    start_new_thread(main,(username,api_key,scheduled_algo)

# %%
algo_data_table =db['test_statergies']
stat = test_col.find_one({'_id': "NF920"})
print(stat)

# %%
from _thread import start_new_thread
def scheduled_task():
    client = pymongo.MongoClient("mongodb+srv://aaush:AaushMongoTestAccount@gopassive.niccs6s.mongodb.net/?retryWrites=true&w=majority",ssl_cert_reqs=ssl.CERT_NONE)
    db = client['AlgoTrade']
    scheduler_col =db['scheduled_data']
    algo_data_col =db['test_statergies']
    all_scheduled_data = list(scheduler_col.find({}))
    
    
    for scheduled_data in all_scheduled_data:
        username = scheduled_data['username']
        api_key = scheduled_data['api_key']
        scheduled_algo = scheduled_data['scheduled_algo']
        status = scheduled_data['status']
        algo_data = algo_data_col.find_one({'_id':scheduled_algo })
        
        start_new_thread(main,(username,api_key,algo_data))
        print("STARTED THE ALGO FOR",username)

# %%
info = alice.get_instrument_by_token('INDICES', 26000)
x = (alice.get_scrip_info(info))
print(x['LTP'])
# (LTP/100)*100)
info = 0
strike = int(round(float(alice.get_scrip_info(alice.get_instrument_by_token('INDICES', 26009))['LTP'])/100)*100)
print(strike)

# %%
curr_ltp = 42408.8
print(int(round(curr_ltp/50)*50))

# %%
d= {'78496265965160':50,
    '87845158484544':65,
    
   }

# %%
class alice_blue:
    
    def __init__(self,name):
        self.name = name
        self.ordernumbers = ordernumbers
        self.sl_orders = sl_orders
        self.instrument = instrument
        self.strike = strike
        self.quantity = quantity
        self.start_time = start_time
        self.exit_time = exit_time
        self.move_sl_to_cost = move_sl_to_cost
        self.auto_squareoff = auto_squareoff
        
    def main(self):
        print(self.name)

    def socket_open():  # Socket open callback function
        print("Connected")
        global socket_opened
        socket_opened = True
        if subscribe_flag:  # This is used to resubscribe the script when reconnect the socket.
            alice.subscribe(subscribe_list)

    def socket_close():  # On Socket close this callback function will trigger
        global socket_opened, ltp_bnf
        socket_opened = False
        ltp_bnf = 0
        print("Closed")

    def socket_error(message):  # Socket Error Message will receive in this callback function
        global ltp_bnf
        ltp_bnf = 0
        print("Error :", message)

    def feed_data(message):  # Socket feed data will receive in this callback function
        global ltp_bnf, subscribe_flag
        feed_message = json.loads(message)
    #     ltp_bnf = feed_message['lp'] if 'lp' in feed_message else ltp_bnf
    #     print(ltp_bnf)

        if feed_message["t"] == "ck":
    #         print("Connection Acknowledgement status :%s (Websocket Connected)" % feed_message["s"])
            subscribe_flag = True
    #         print("subscribe_flag :", subscribe_flag)
            pass
        elif feed_message["t"] == "tk":
    #         print("Token Acknowledgement status :%s " % feed_message)
    #         print("-------------------------------------------------------------------------------")
            pass
        else:
    #         print("Feed :", feed_message)
            ltp_bnf = feed_message[
                'lp'] if 'lp' in feed_message else ltp_bnf  # If ltp_bnf in the response it will store in ltp_bnf variable
            print(ltp_bnf)

    def order_status_function(number):
        order_status= None
        print(type(number))
        for i in range(3):
            print("for")
            try:
                print("try")
                order_details = alice.get_order_history(number)
                order_status = order_details['Status']
                print(order_status)
                return order_status
            except Exception as e:
                print({e})
                sleep(25)
                pass

    def ap_generator(oid):
        order_details =alice.get_order_history(str(oid))
        avg_price = order_details['Avgprc']
        return avg_price

    def get_oid(order_placed_output):
        oid = order_placed_output[0]['NOrdNo']
        return oid
    
    def place_orders():
        oid = alice_place_order(ichnsicjsocks)
    
    def place_sl_orders():
        pass
    
    def auto_squareoff():
        pass
    
    def sl_to_cost():
        pass

# %%
x = [True,False,True]
print(type(x[1]))

# %%
class alice_blue():
    
    def main():
        pass
    
    def __init__(self):
        print("CALLED")
        
    def place_orders(self):
        print("place_orders")
        order = alice.place_order(transaction_type = transaction_type,
                     instrument = instrument,
                     quantity = qty,
                     order_type = OrderType.Market,
                     product_type = ProductType.Intraday,
                     price = 0.0,
                     trigger_price = None,
                     stop_loss = None,
                     square_off = None,
                     trailing_sl = None,
                     is_amo = False)
                        
#         return 
#                      order_tag='order1')
        
        
    def place_sl_orders():
        print("place_sl_orders called")
        
    def get_atm_data():
        print("GETDATA")
    
tran ="ABC"
print(alice_blue.place_orders(tran))

# %%
def test(x,y,z=0):
    print(f"THIS IS TEST {x}")
    
test(x=10,y="STR")

# %%
x = -1

if x < 0:
    raise KeyboardInterrupt
    raise Exception("Sorry, no numbers below zero")
    raise TypeError("Only integers are allowed")

# %%
class doWorkWithItems():
    def __init__(self, *args):
        try:
             self.args = dict(args)
        except TypeError:
            pass
             #What to do if invalid parameters are passed


obj = doWorkWithItems( ("Name", "John"), ("Age", 45), ("Occupation", "Professional Example"))

obj.args

# %%
from pya3 import *
from datetime import datetime

username = '285915'
api_key = 'eUmxHh0mSZujQ4xGn2Bi5BOgDtVoalyG4ssEzPmFeJy0d0ocPtRhCYC3xZyRZ4S2DPfUq4DsHQxcLqPjnG0CNht5Y1Y5e8XrP8zB97G4ocBf7hljkKKNfsmHyWu2BFb9'
alice = Aliceblue(user_id=username,api_key=api_key)
print(alice.get_session_id())
# print(alice.get_netwise_positions()) # get all netwise positions
# Out:
# {'stat': 'Ok', 'sessionID': ''}

# %%
ins = 26009
stk_rng = 100
strike = int(round(float(alice.get_scrip_info(alice.get_instrument_by_token('INDICES', ins))['LTP'])/stk_rng)*stk_rng)
print(strike)
# Out:
# 42200

# %%
from _thread import start_new_thread
import datetime
import time
from pya3 import *
from datetime import datetime

username = '285915'
api_key = 'eUmxHh0mSZujQ4xGn2Bi5BOgDtVoalyG4ssEzPmFeJy0d0ocPtRhCYC3xZyRZ4S2DPfUq4DsHQxcLqPjnG0CNht5Y1Y5e8XrP8zB97G4ocBf7hljkKKNfsmHyWu2BFb9'
alice = Aliceblue(user_id=username,api_key=api_key)
print(alice.get_session_id())




# instruments =['NIFTY','NIFTY','NIFTY','NIFTY','NIFTY','NIFTY','NIFTY','NIFTY','NIFTY','NIFTY','NIFTY','NIFTY']
# strikes = [18000,18200,18100,18000,18200,18100,18000,18250,17900,18050,18250,18150]

instruments =['NIFTY','NIFTY','NIFTY']
strikes = [18000,18200,18100]
oid_list = []

def place_order(instrument,strike):
#     print(datetime.datetime.now())
    if instrument =='BANKNIFTY':
        qty = 25
    else:
        qty = 50
    print('order done for',instrument,strike)
    
    inst = alice.get_instrument_for_fno(exch = 'NFO',symbol=instrument,expiry_date="2022-12-29",is_fut=False,strike=strike,is_CE=True)
    print("INST",inst)
    
    order_id = alice.place_order(transaction_type = TransactionType.Buy,
                     instrument = inst,
                     quantity = qty ,
                     order_type = OrderType.Market,
                     product_type = ProductType.Intraday,
                     price = 0.0,
                     trigger_price = None,
                     stop_loss = None,
                     square_off = None,
                     trailing_sl = None,
                     is_amo = False)
    
    print(order_id)
    oid_list.append(order_id['NOrdNo'])
    
#     time.sleep(2)
#     print(datetime.datetime.now())


legcount = 12
start_time = datetime.now()
print("started")
for i in range (len(instruments)):
    print(i)
    start_new_thread(place_order,(instruments[i],strikes[i]))
    print("HERE")
    print("ORDERS ARE NOT PLACED STILL THIS IS PRINTING")
    
end_time = datetime.now()
print("TOTAL TIME TAKEN",format(end_time - start_time))
print(oid_list)

# %%
x = {'stat': 'Ok', 'NOrdNo': '221220000252424'}
if not x['stat'] =='Ok':
    print("REPLACE THE ERROR")

# %%
from datetime import datetime
start_time = datetime.now()
# do your work here
time.sleep(3)
end_time = datetime.now()
print("TOTAL TIME TAKEN",format(end_time - start_time))
print('Duration: {}'.format(end_time - start_time))

# %%
x = [{'Instname': 'OPTIDX', 'Expdate': '22 Dec, 2022', 'CFsellqty': '0', 'Opttype': 'CE', 'Token': '51466', 'CFSellavgprc': '0.00', 'sSqrflg': 'Y', 'unrealisedprofitloss': '1,917.50', 's_NetQtyPosConv': 'N', 'FillbuyamtCF': '0.00', 'Sqty': '25', 'Sellavgprc': '135.20', 'actid': '612538', 'netbuyamt': '0.00', 'Pcode': 'MIS', 'Bqty': '0', 'NetBuyavgprc': '0.00', 'Exchange': 'NFO', 'companyname': '', 'netbuyqty': '0', 'realisedprofitloss': '0.00', 'Fillsellamt': '3,380.00', 'Netqty': '-25', 'Symbol': 'BANKNIFTY', 'LTP': '58.50', 'BLQty': 25.0, 'Fillbuyamt': '0.00', 'Fillsellqty': '25', 'Tsym': 'BANKNIFTY22D2243600CE', 'CFbuyqty': '0', 'Buyavgprc': '0.00', 'netSellamt': '3,380.00', 'MtoM': '1,917.50', 'stat': 'Ok', 'FillsellamtCF': '0.00', 'PriceDenomenator': '1', 'netsellqty': '25', 'PriceNumerator': '1', 'posflag': 'false', 'Stikeprc': '43600.0', 'BEP': '135.20', 'Series': 'XX', 'GeneralDenomenator': '1', 'Type': 'DAY1', 'Netamt': '3,380.00', 'NetSellavgprc': '135.20', 'CFBuyavgprc': '0.00', 'Fillbuyqty': '0', 'GeneralNumerator': '1', 'Exchangeseg': 'nse_fo', 'discQty': 'NA'}, {'Instname': 'OPTIDX', 'Expdate': '22 Dec, 2022', 'CFsellqty': '0', 'Opttype': 'PE', 'Token': '51467', 'CFSellavgprc': '0.00', 'sSqrflg': 'Y', 'unrealisedprofitloss': '0.00', 's_NetQtyPosConv': 'N', 'FillbuyamtCF': '0.00', 'Sqty': '25', 'Sellavgprc': '146.25', 'actid': '612538', 'netbuyamt': '4,421.25', 'Pcode': 'MIS', 'Bqty': '25', 'NetBuyavgprc': '176.85', 'Exchange': 'NFO', 'companyname': '', 'netbuyqty': '25', 'realisedprofitloss': '-765.00', 'Fillsellamt': '3,656.25', 'Netqty': '0', 'Symbol': 'BANKNIFTY', 'LTP': '513.55', 'BLQty': 25.0, 'Fillbuyamt': '4,421.25', 'Fillsellqty': '25', 'Tsym': 'BANKNIFTY22D2243600PE', 'CFbuyqty': '0', 'Buyavgprc': '176.85', 'netSellamt': '3,656.25', 'MtoM': '-765.00', 'stat': 'Ok', 'FillsellamtCF': '0.00', 'PriceDenomenator': '1', 'netsellqty': '25', 'PriceNumerator': '1', 'posflag': 'false', 'Stikeprc': '43600.0', 'BEP': '0.00', 'Series': 'XX', 'GeneralDenomenator': '1', 'Type': 'DAY1', 'Netamt': '-765.00', 'NetSellavgprc': '146.25', 'CFBuyavgprc': '0.00', 'Fillbuyqty': '25', 'GeneralNumerator': '1', 'Exchangeseg': 'nse_fo', 'discQty': 'NA'}]
print(len(x))
print(x[0])
print(x[1])
print("-------------------------------------------------------------------------->>")
MTM = 0
for i in range(len(x)):
    m = (x[i]['MtoM'])
    print(m)
    MTM += (float(m.replace(',','')))
            
print(MTM)

# %%
a='191.7'
x = float(a.replace(',',''))
print(x)

# for f in a 
# print(int(a))

# %%
x = -9
z = (50*x)
print(z)
print(500+z)

# %%
LTP = 17972
low_side_strike = "OTM-1"
# ATM_STRIKE = int(round(LTP/100)*100)

ind_range = 50
ATM_STRIKE = int(round(LTP/50)*50)

if low_side_strike == 'OTM-1':
    ATM_STRIKE += ind_range
print(ATM_STRIKE)

# %%
ce_avg_p = 1500
stoploss_ce_percent = 10.0

ce_sl_point = (float(ce_avg_p))*stoploss_ce_percent/100
ce_sl_price = (0.05* round((float(ce_avg_p) + (ce_sl_point))/0.05))
print(ce_sl_price)
# print((0.05* round((float(ce_avg_p))*stoploss_ce_percent/100)/0.05))

# %%
put_sell_avg_price = 100
tgt_point = 80
print(0.05 * round((float(put_sell_avg_price) * (1-tgt_point))/0.05))
# Out:
# -7900.0

# %%
x = {'csrfmiddlewaretoken': ['EB2oocencc0KRPRJSYrSFxidHQDb5K6RMBpTP7YxeiJBKt30adPkD0A0Vft4iotB'],
 'legcount': ['2'],
 'algoname': ['TEST'],
 'instrument': ['Nifty', 'Nifty'],
 'segment': ['Options', 'Options'],
 'options': ['PE', 'PE'],
 'transcation_type': ['Buy', 'Buy'],
 'strike': ['ATM', 'ATM'],
 'quantity': ['25', '10'],
 'target': ['300', '100'],
 'stoploss': ['100', '50'],
 'startTime': ['01:06'],
 'endTime': ['01:26'],
 'move_sl_to_cost': ['move_sl_to_cost'],
 'square_off': ['square_off']}

print((x['startTime'][0])[:2])

def get_time(data):
    print(data)
    print(type(data))
    
    if data[0] == '0':
        time = int(data[1])
    else:
        time = int(data)
    return time

data = {"_id": x["algoname"][0],
  "legcount": x["legcount"],
   "algoname":  x["algoname"],
   "instrument":x["instrument"],
   "segment": x["segment"],
   "options": x["options"],
   "transcation_type": x["transcation_type"],
   "strike": x["strike"],
   "lots": x["quantity"],
   "target": x["target"],
   "stoploss": x["stoploss"], 
    "start_hr" : get_time((x['startTime'][0])[:2]),
    "start_min" : get_time((x['startTime'][0])[3:]),
   "end_hr": get_time((x['endTime'][0])[:2]),
   "end_min": get_time((x['endTime'][0])[3:]),
   "move_sl_to_cost": None,
   "square_off": None
}
print(data)
# Out:
# 01
# 01
# <class 'str'>
# 06
# <class 'str'>
# 01
# <class 'str'>
# 26
# <class 'str'>
# {'_id': ['TEST'], 'legcount': ['2'], 'algoname': ['TEST'], 'instrument': ['Nifty', 'Nifty'], 'segment': ['Options', 'Options'], 'options': ['PE', 'PE'], 'transcation_type': ['Buy', 'Buy'], 'strike': ['ATM', 'ATM'], 'lots': ['25', '10'], 'target': ['300', '100'], 'stoploss': ['100', '50'], 'start_hr': 1, 'start_min': 6, 'end_hr': 1, 'end_min': 26, 'move_sl_to_cost': None, 'square_off': None}

# %%
time = "19:15"
def get_time(time):
    if time[0] == '0':
        start_hr = int(time[1])
        start_min = int(time[4])
    
    else:
        start_hr = int(time[:2])
        start_min = int(time[3:])
    return start_hr,start_min
print((get_time("01:08")))
# print(start_hr,start_min)
# Out:
# <class 'tuple'>

# %%
time = "19:15"
def get_time(data):
    if data[0] == '0':
        time = int(time[1])
    else:
        time = int(time)
    return time
print((get_time("15")))
# print(start_hr,start_min)
time = "10:50"
print(time[3:])
# Out:
# 15
# 50

# %%
def strike_checker(x):
    if x[:3] == 'ITM':
        if (len(x))> 4:
            stk = -(int(x[3]+x[4]) )
        else:
            stk = -(int(x[3]))

    if x[:3] == 'OTM':
        if (len(x))> 4:
            stk = (int(x[3]+x[4]) )
        else:
            stk = (int(x[3]))

    if x[:3] == "ATM":
        stk = 0
    return stk
x = "OTM5"
strike_checker(x)
# Out:
# 5

# %%
y= "5"
print(-(int(y)))
# Out:
# -5
